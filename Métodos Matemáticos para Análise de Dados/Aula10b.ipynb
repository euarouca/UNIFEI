# %% [markdown]
# ## Criação de histogramas com Seaborn
# Nesta aula analisaremos o índice de percepção de corrupção no setor público nos diferentes países do globo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CPI_2014.csv', encoding='latin-1')

# %%
df
# Out:
#      Rank        Country  CPI_2014 Continent
# 0       1        Denmark        92    Europe
# 1       2    New Zealand        91   Oceania
# 2       3        Finland        89    Europe
# 3       4         Sweden        87    Europe
# 4       5         Norway        86    Europe
# ..    ...            ...       ...       ...
# 170   171    South Sudan        15    Africa
# 171   172    Afghanistan        12      Asia
# 172   173          Sudan        11    Africa
# 173   174  Korea (North)         8      Asia
# 174   174        Somalia         8    Africa
#
# [175 rows x 4 columns]

# %%
df[df['Country'] == 'Brazil']
# Out:
#     Rank Country  CPI_2014      Continent
# 68    69  Brazil        43  South America

# %%
sns.displot(df['CPI_2014'], kde=False)
sns.set_style('darkgrid')
plt.title('Indice de percepcao de corrupcao de 2014')
plt.xlabel('Nivel de corrupcao')
plt.ylabel('Quantidade')
plt.axvline(60, color='k', linestyle='--')

# %% [markdown]
# Exercício \
# Criar um histograma apenas com países da Europa.

# %%
european = df[df['Continent'] == 'Europe']
# Out:
#      Rank                 Country  CPI_2014 Continent
# 0       1                 Denmark        92    Europe
# 2       3                 Finland        89    Europe
# 3       4                  Sweden        87    Europe
# 4       5                  Norway        86    Europe
# 5       5             Switzerland        86    Europe
# 7       8             Netherlands        83    Europe
# 8       9              Luxembourg        82    Europe
# 11     12                 Germany        79    Europe
# 12     12                 Iceland        79    Europe
# 13     14          United Kingdom        78    Europe
# 14     15                 Belgium        76    Europe
# 18     17                 Ireland        74    Europe
# 22     23                 Austria        72    Europe
# 25     26                 Estonia        69    Europe
# 26     26                  France        69    Europe
# 31     31                  Cyprus        63    Europe
# 32     31                Portugal        63    Europe
# 34     35                  Poland        61    Europe
# 37     37                   Spain        60    Europe
# 39     39               Lithuania        58    Europe
# 40     39                Slovenia        58    Europe
# 43     43                  Latvia        55    Europe
# 44     43                   Malta        55    Europe
# 47     47                 Hungary        54    Europe
# 49     50                 Georgia        52    Europe
# 52     53          Czech Republic        51    Europe
# 53     54                Slovakia        50    Europe
# 60     61                 Croatia        48    Europe
# 64     64    The FYR of Macedonia        45    Europe
# 69     69                Bulgaria        43    Europe
# 70     69                  Greece        43    Europe
# 71     69                   Italy        43    Europe
# 72     69                 Romania        43    Europe
# 75     76              Montenegro        42    Europe
# 77     78                  Serbia        41    Europe
# 80     80  Bosnia and Herzegovina        39    Europe
# 93     94                 Armenia        37    Europe
# 104   103                 Moldova        35    Europe
# 109   110                 Albania        33    Europe
# 112   110                  Kosovo        33    Europe
# 118   119                 Belarus        31    Europe
# 143   142                 Ukraine        26    Europe

# %%
sns.histplot(european['CPI_2014'], kde=False)
sns.set_style('darkgrid')
plt.title('Indice de percepcao de corrupcao de 2014')
plt.xlabel('Nivel de corrupcao')
plt.ylabel('Quantidade')
plt.axvline(60, color='k', linestyle='--')
