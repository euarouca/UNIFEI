# %% [markdown]
# ## Gráfico de Linhas
# Vamos criar um gráfico de linhas para analisar a evolução do preço das ações das empresas Tesla e Apple.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ticker = yf.Ticker('TSLA')
df = ticker.history(interval='1d', start='2020-01-01')

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   28.299999   28.713333   28.114000   28.684000
# 2020-01-03 00:00:00-05:00   29.366667   30.266666   29.128000   29.534000
# 2020-01-06 00:00:00-05:00   29.364668   30.104000   29.333332   30.102667
# 2020-01-07 00:00:00-05:00   30.760000   31.441999   30.224001   31.270666
# 2020-01-08 00:00:00-05:00   31.580000   33.232666   31.215334   32.809334
# ...                               ...         ...         ...         ...
# 2025-04-09 00:00:00-04:00  224.690002  274.690002  223.880005  272.200012
# 2025-04-10 00:00:00-04:00  260.000000  262.489990  239.330002  252.399994
# 2025-04-11 00:00:00-04:00  251.839996  257.739990  241.360001  252.309998
# 2025-04-14 00:00:00-04:00  258.359985  261.799988  245.929993  252.350006
# 2025-04-15 00:00:00-04:00  249.860001  258.750000  247.550003  255.050003
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# Vamos agora utilizar o dataset LifeExpectancy para criar um gráfico de barras.

# %%
df = pd.read_csv('lifeExpectancy.csv')
df.head()
# Out:
#       Countries  Males  Females
# 0       Algeria     69       73
# 1        Angola     50       53
# 2         Benin     58       61
# 3  Burkina Faso     55       56
# 4       Burundi     52       56

# %% [markdown]
# Nosso gráfico deve permitir comparar a expectativa de vida de homens e mulheres de países africanos.

# %%
plt.rcParams['figure.figsize'] = [12, 8]
df.plot(x='Countries', kind='bar', stacked=False)
plt.title('Expectativa de vida de homens e mulheres em paises africanos')
plt.xlabel('Paises')
plt.ylabel('Expectativa')
plt.show()

# %% [markdown]
# Para uma melhor visualização, podemos dividir o dataset. A seguir vamos tomar os 15 primeiros países do dataset.

# %%
df2 = df.head(15)

plt.rcParams['figure.figsize'] = [12, 8]
df2.plot(x='Countries', kind='bar', stacked=False)
plt.title('Expectativa de vida de homens e mulheres em paises africanos')
plt.xlabel('Paises')
plt.ylabel('Expectativa')
plt.show()
